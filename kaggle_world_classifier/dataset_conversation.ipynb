# %% [markdown]
# # GLM-5.2 Conversation
# Dieses Notebook klassifiziert nur dieses Dataset, zeilenweise.

# %%
from pathlib import Path
import subprocess, sys
DATASET = 'ianncity/GLM-5.2-Conversation'
OUTPUT = Path('/kaggle/working/world_knowledge_conversation')
candidates = [Path('/kaggle/working/main.py'), Path('main.py'), Path('../main.py')]
script = next((p for p in candidates if p.exists()), None)
if script is None: raise FileNotFoundError('main.py als Notebook-Input hinzufügen')
subprocess.run([sys.executable, str(script), '--dataset', DATASET, '--output-dir', str(OUTPUT)], check=True)
