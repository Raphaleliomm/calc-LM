# %% [markdown]
# # MetaMathQA
# Nur dieses Dataset, zeilenweise.

# %%
from pathlib import Path
import subprocess, sys
DATASET='meta-math/MetaMathQA'
OUTPUT=Path('/kaggle/working/world_knowledge_metamathqa')
script=next((p for p in [Path('/kaggle/working/main.py'),Path('main.py'),Path('../main.py')] if p.exists()),None)
if script is None: raise FileNotFoundError('main.py als Notebook-Input hinzufügen')
subprocess.run([sys.executable,str(script),'--dataset',DATASET,'--output-dir',str(OUTPUT)],check=True)
